# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# libraries important for perceptron

# %%
df=pd.read_csv('./DATASETS/placement.csv')
print(df.head())
print(df.shape)

sns.scatterplot( x=df['cgpa'], y=df['iq'], hue=df['placement'])
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0
# (100, 4)
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
x=df.iloc[:,1:3]
print(x.head)
y=df.iloc[:,-1]
print(y.head)
# Out:
# <bound method NDFrame.head of     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]>
# <bound method NDFrame.head of 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64>

# %% [markdown]
# IMPORTING THE PERCEPTRON FROM SKLEARN

# %%
from sklearn.linear_model import Perceptron
P=Perceptron()

P.fit(x,y)
print(P.coef_)
print(P.intercept_)

from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.values,y.values, clf=P,legend=2)
# Out:
# [[1218.5 -193. ]]
# [-7.]
# e:\MLJOURNEY\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['cgpa'],df['iq'],c=df['placement'],cmap='winter',s=100)
